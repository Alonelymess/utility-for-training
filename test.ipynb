# %%
import time
import random
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager as CM
# import undetected_chromedriver.v2 as uc
import undetected_chromedriver as uc
from selenium.webdriver.chrome.service import Service
from selenium_stealth import stealth
import pickle
import json

print('=====================================================================================================')
print('Heyy, you have to login manully on tiktok, so the bot will wait you 1 minute for loging in manually!')
print('=====================================================================================================')
# time.sleep(8)
print('Running bot now, get ready and login manually...')
# time.sleep(4)
# Out:
# ...
# Heyy, you have to login manully on tiktok, so the bot will wait you 1 minute for loging in manually!
# ...
# Running bot now, get ready and login manually...

# %%
service = Service(executable_path=CM().install())
bot = uc.Chrome()
options = webdriver.ChromeOptions()
options.add_argument("start-maximized")
options.add_argument("--profile-directory=Default")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
bot = webdriver.Chrome(service=service, options=options)

stealth(bot,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=True,
        )
bot.set_window_size(800, 800)

# %%
bot.get('https://www.tiktok.com/login')
ActionChains(bot).key_down(Keys.CONTROL).send_keys(
    '-').key_up(Keys.CONTROL).perform()
ActionChains(bot).key_down(Keys.CONTROL).send_keys(
    '-').key_up(Keys.CONTROL).perform()
print('Waiting 50s for manual login...')
# time.sleep(50)
# Out:
# Waiting 50s for manual login...

# %%
# First time
pickle.dump(bot.get_cookies(), open("cookies.pkl", "wb"))

# %%
# Next time
cookies = pickle.load(open("cookies.pkl", "rb"))
for cookie in cookies[:1]:
    print(cookie)
    # bot.add_cookie(cookie)
# Out:
# {'domain': '.www.tiktok.com', 'expiry': 1722866825, 'httpOnly': False, 'name': 'perf_feed_cache', 'path': '/', 'sameSite': 'Lax', 'secure': True, 'value': '{%22expireTimestamp%22:1722607200000%2C%22itemIds%22:[%227371791442550738177%22%2C%227396118415707999496%22%2C%227395038008430415121%22]}'}

# %% [markdown]
# # Get cookies

# %%
import sqlite3 as sq

# %%
conn = sq.connect('database.db')

# %%
# Create a cursor object
cursor = conn.cursor()

# Execute a SQL query to list all the tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Tables in the database:")
for table in tables:
    print(table[0])
# Out:
# Tables in the database:
# Accounts
# Sessions

# %%
cursor.execute("SELECT * FROM Accounts")
accounts = cursor.fetchall()
for account in accounts[:1]:
    print(account)
# Out:
# ('2d7d6e44-b728-45e3-bc4d-8948f1c7ad21', 'AbbieGDebbyK611@thanhpro.kr.bin', 'Hntb2022', None, 1, 1, '[{"name":"COMPASS","value":"dynamite-ui=CgAQtanjsQYaZwAJa4lXaCEJWKjS8Tk9Kkwpggynd3BpXmlKXYUUMiRREjDHmITR0wz8-Lmhx3qwWY51J4wUQPDrcLjw69simpXXK3IuCwuNuaEDcNuoUn0kVtc_Vy3_9pDKH2un4Tn88XP37J1F_b4gATAB:dynamite=CgAQvKnjsQYagAEACWuJVwDyKoCeyWrxaIb5Psxy2sRPuWNOoAwOyMqUTLFMp6acA-XQpxq3kjhODDGtkacEChzSMi5UTWPvgnFQPhb8u29d3FW26v2h7Z0zTV9d401XA2yRXOX9SjBd1jxRW7GTEPvnzMhMjML07P_4bD0_K0muAVTySQVp_8xccDAB","domain":"chat.google.com","path":"/u/0/webchannel/","expires":1715860909.167449,"size":373,"httpOnly":true,"secure":true,"session":false,"sameSite":"None","priority":"Medium","sameParty":false,"sourceScheme":"Secure","sourcePort":443},{"name":"COMPASS","value":"gmail_ps=CrMBAAlriVcAvk-3A1aVLmP7HV9zgsyY05XTK7d41qGH3D6HR2NuX5GFcbpSJE6Ksr9m7YGGwOfxuCoy3DTTXJwVxoNNCJ7dbXgvsI4yM-aO-cfkYaOpReEQPpe2NmMohxVIreQ16GPbycpvJekBOxnUN4YxCSq-jWDIDHAdw8Obk0csT5ssZRyCYAHQXOpwkPJN_m3he5wMhag1qDzfXy6NE8xX5Cav3LurY
# ...

# %%
list_cookies = json.loads(account[6])

# %%
for cookie in list_cookies:
    if 'tiktok' in cookie['domain']:
        bot.add_cookie(cookie)

# %%
cursor.execute("SELECT * FROM Sessions")
sessions = cursor.fetchall()
for session in sessions[:1]:
    print(session)
# Out:
# ('c482ad4c-fb6a-4482-b702-35953280e341', 'nnlan.scout@gmail.com', 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJsb2NhbGhvc3QiLCJhdWQiOiJsb2NhbGhvc3QiLCJzdWIiOiJubmxhbi5zY291dEBnbWFpbC5jb20iLCJleHAiOjE3MTUzNjAzNDQ2MjEsImlhdCI6MTcxNTM1Njc0NDYyMX0.JKHJdZpku68UQ5FJtwr5cLP9ivW51JXwRJhYaZkpX5s', '', '5f0c5020-c370-11ee-a291-53fb8e8d1224', '2024-05-10 22:58:18.8404189', '2024-05-14 05:48:28.226394')

# %%
# Close the connection
conn.close()

# %% [markdown]
# # Create more "human" bot

# %%
bot.get('https://www.tiktok.com')

# %%
# Click on profile
bot.find_element(By.CSS_SELECTOR, 'a[data-e2e="nav-profile"]').click()

# %%
# Upload picture
bot.find_element(By.CSS_SELECTOR, 'button[type="button"][class="e33dl3i1 css-2p8csz-Button-StyledEditButton ehk74z00"]').click()
bot.find_element(By.CSS_SELECTOR, 'div[class="e13yu7jj21 css-1t7819m-DivContainer-StyledAvatar e1vl87hj1"]').click()

# %%
# Upload video
# bot.find_element(By.CSS_SELECTOR, 'div[data-e2e="upload-icon"]').click()
# time.sleep(2)
input_vid = bot.find_element(By.CSS_SELECTOR, "input[type='file'][accept='video/*']")
time.sleep(3)
input_vid.send_keys(r"G:\Anh\LANCS\videos\cut.mp4")

# %%
description = bot.find_element(By.CSS_SELECTOR, 'div[class="DraftEditor-editorContainer"]')
edit = description.find_element(By.CSS_SELECTOR, 'span[data-text="true"]')
edit.send_keys('This is a test video')
post = bot.find_element(By.CSS_SELECTOR, 'button[type="button"][class="TUXButton TUXButton--default TUXButton--large TUXButton--primary"]').click()

# %% [markdown]
# # Like, comment and follow

# %%
bot.quit()

# %%
url = 'https://l.facebook.com/l.php?u=https%3A%2F%2Fvt.tiktok.com%2FZSYTcoHh2%2F%3Ffbclid%3DIwZXh0bgNhZW0CMTAAAR2m3Z9J5Oa07Jvq76BeSzc_O0ijTuEYZxvBYGB9l3tZ2gpxNjhx0_w6Fug_aem_Kg7fV9_VIUyGrs9hgQUoJQ&h=AT0_QZkfDLHesrKa9dhlj81c-b9xUKEScnglk2hRKze6JOgaFCAEZb-muxe3NPQHWbO9Mi7NBxjms-ava4aQsQfLtm2o9FX0YJNLEjJII1MJHbutoxSF9Z17xA015R1q0Oz7LMnkeCwMIr0'
bot.get(url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\ciltr\miniconda3\envs\py39\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\ciltr\miniconda3\envs\py39\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Users\ciltr\miniconda3\envs\py39\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
# ...

# %%
pause_button = bot.find_element(By.CSS_SELECTOR,
                                "div[class='css-15ixi88-DivPlayIconContainer eo7etkj4']")
                                # "div[class='css-q1bwae-DivPlayIconContainer e1ya9dnw8']")
pause_button.click()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\ciltr\miniconda3\envs\py39\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 pause_button = bot.find_element(By.CSS_SELECTOR,
#       2                                 "div[class='css-15ixi88-DivPlayIconContainer eo7etkj4']")
#       3                                 # "div[class='css-q1bwae-DivPlayIconContainer e1ya9dnw8']")
#       4 pause_button.click()
#
# ...

# %%
follow_button = bot.find_element(By.CSS_SELECTOR, "button[class='e17fzhrb6 css-1obmd97-Button-StyledFollowButtonTux e1v8cfre0']")
follow_button.click()

# %%
button_like = bot.find_element(By.CSS_SELECTOR, "button[type='button'][class='css-rninf8-ButtonActionItem edu4zum0'] span[data-e2e='like-icon']")
button_like.click()

# %%
scroll_to_comment = bot.find_element(By.CSS_SELECTOR, "button[type='button'][class='css-rninf8-ButtonActionItem edu4zum0']")
button_comment = bot.find_element(By.CSS_SELECTOR, "div[data-e2e='comment-text'][class='css-4p7h1x-DivInputEditorContainer e1rzzhjk3']")
button_comment.click()

# %%
comment_span = bot.find_element(By.CSS_SELECTOR, "div[class='DraftEditor-editorContainer")
# Find the child br element
child_br = bot.find_element(By.CSS_SELECTOR, "br[data-text='true']")
child_br.send_keys('Love youuu')
post_button = bot.find_element(By.CSS_SELECTOR, "div[aria-disabled='false'][aria-label='Post'][role='button']")
post_button.click()
